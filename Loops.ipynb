# %% [markdown]
# <a href="https://colab.research.google.com/github/HOKFIRE/Coding-Club/blob/main/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = 2
while number < 11:
  print(number)
  number += 2
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
while True:
  print("and over")
# Out:
# Streaming output truncated to the last 5000 lines.
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# and over
# ...
